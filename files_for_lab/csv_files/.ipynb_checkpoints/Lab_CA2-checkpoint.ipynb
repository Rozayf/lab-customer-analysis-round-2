# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('marketing_customer_analysis.csv')
data = data.drop(['Unnamed: 0'],axis=1)

# %%
data
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
data.shape
# Out:
# (10910, 25)

# %%
data.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
data.describe().T
# Out:
#                                  count          mean           std  \
# Customer Lifetime Value        10910.0   8018.241094   6885.081434
# Income                         10910.0  37536.284785  30359.195670
# Monthly Premium Auto           10910.0     93.196059     34.442532
# Months Since Last Claim        10277.0     15.149071     10.080349
# Months Since Policy Inception  10910.0     48.091934     27.940675
# Number of Open Complaints      10277.0      0.384256      0.912457
# Number of Policies             10910.0      2.979193      2.399359
# Total Claim Amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  4014.453113   5771.147235
# Income                            0.000000     0.000000  33813.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# ...

# %%
data.describe(include=[object]).T
# Out:
#                    count unique            top  freq
# customer           10873   9134        DQ50258     5
# state              10259      5     California  3548
# response           10259      2             No  8795
# coverage           10873      3          Basic  6635
# education          10873      5       Bachelor  3259
# effective to date  10873     59        1/27/11   239
# employmentstatus   10873      5       Employed  6764
# gender             10873      2              F  5554
# location code      10873      3       Suburban  6879
# marital status     10873      3        Married  6298
# policy type        10873      3  Personal Auto  8102
# policy             10873      9    Personal L3  4108
# renew offer type   10873      4         Offer1  4471
# sales channel      10873      4          Agent  4111
# vehicle class      10265      6  Four-Door Car  5200
# vehicle size       10265      3        Medsize  7233
# vehicle type        5408      1              A  5408

# %%
data.columns = data.columns.str.lower()

# %%
data.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'response', 'coverage',
#        'education', 'effective to date', 'employmentstatus', 'gender',
#        'income', 'location code', 'marital status', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies', 'policy type',
#        'policy', 'renew offer type', 'sales channel', 'total claim amount',
#        'vehicle class', 'vehicle size', 'vehicle type'],
#       dtype='object')

# %%
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
import datetime

# %%
data['month'] = pd.DatetimeIndex(data['effective to date']).month
data.head(10)
# Out:
#   customer       state  customer lifetime value response  coverage  \
# 0  DK49336     Arizona              4809.216960       No     Basic
# 1  KX64629  California              2228.525238       No     Basic
# 2  LZ68649  Washington             14947.917300       No     Basic
# 3  XL78013      Oregon             22332.439460      Yes  Extended
# 4  QA50777      Oregon              9025.067525       No   Premium
# 5  HO81102         NaN              4745.181764      NaN     Basic
# 6  IW72280  California              5035.035257       No     Basic
# 7  IH64929  California              4956.247235       No     Basic
# 8  FM55990  California              5989.773931      Yes   Premium
# 9  QX31376      Oregon             17114.328150       No  Extended
#
#               education effective to date employmentstatus gender  income  \
# 0               College           2/18/11         Employed      M   48029
# 1               College           1/18/11       Unemployed      F       0
# ...

# %%
data['quarter'] = pd.DatetimeIndex(data['effective to date']).quarter
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
data['month'].value_counts()
# Out:
# 1    5799
# 2    5074
# Name: month, dtype: int64

# %%
percent_missing = data.isnull().sum() * 100 / len(data)
missing_value_data = pd.DataFrame({'column_name': data.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_data
# Out:
#                                                  column_name  percent_missing
# customer                                            customer         0.000000
# state                                                  state         5.647016
# customer lifetime value              customer lifetime value         0.000000
# response                                            response         5.647016
# coverage                                            coverage         0.000000
# education                                          education         0.000000
# effective to date                          effective to date         0.000000
# employmentstatus                            employmentstatus         0.000000
# gender                                                gender         0.000000
# income                                                income         0.000000
# location code                                  location code         0.000000
# ...

# %%
data_frame1 = data.drop(['vehicle type'], axis=1)

## dropped vehicle type because there are more than 50% NaN values.

# %%
data_frame1
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
data_frame1['state'].unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', nan, 'Nevada'],
#       dtype=object)

# %%
data_frame1['state'] = data_frame1['state'].fillna('California')

##added NaN as California because it is the most common

# %%
data_frame1['state'].unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', 'Nevada'],
#       dtype=object)

# %%
data_frame1['response'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data_frame1['response'] = data_frame1['response'].fillna('undefined')

##added NaN as undefined because it makes a big difference IMHO

# %%
data_frame1['response'].unique()
# Out:
# array(['No', 'Yes', 'undefined'], dtype=object)

# %%
data_frame1['months since last claim'].unique()
# Out:
# array([ 7.,  3., 34., 10., nan,  2.,  8., 35., 33., 19., 13.,  5., 24.,
#        25.,  6., 20., 26., 14.,  9., 29., 11.,  1., 18., 16., 30., 12.,
#         4., 22., 31., 21., 28., 17., 15., 32., 23., 27.,  0.])

# %%
data_frame1['months since last claim'].value_counts(dropna=True)
# Out:
# 3.0     623
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     377
# 4.0     372
# 2.0     365
# 5.0     354
# 0.0     353
# 10.0    345
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    306
# 17.0    298
# 14.0    297
# 19.0    275
# 9.0     275
# 23.0    273
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    245
# 24.0    236
# 29.0    233
# 28.0    225
# 31.0    219
# 26.0    211
# 27.0    207
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    156
# 32.0    155
# Name: months since last claim, dtype: int64

# %%
data_frame1['months since last claim'] = data_frame1['months since last claim'].fillna('3.0')

##added NaN as 3.0 because it is the most common and wont skew the mean

# %%
data_frame1['months since last claim'].unique()
# Out:
# array([7.0, 3.0, 34.0, 10.0, '3.0', 2.0, 8.0, 35.0, 33.0, 19.0, 13.0, 5.0,
#        24.0, 25.0, 6.0, 20.0, 26.0, 14.0, 9.0, 29.0, 11.0, 1.0, 18.0,
#        16.0, 30.0, 12.0, 4.0, 22.0, 31.0, 21.0, 28.0, 17.0, 15.0, 32.0,
#        23.0, 27.0, 0.0], dtype=object)

# %%
data_frame1['number of open complaints'].value_counts(dropna=True)
# Out:
# 0.0    8141
# 1.0    1141
# 2.0     414
# 3.0     321
# 4.0     166
# 5.0      67
# Name: number of open complaints, dtype: int64

# %%
data_frame1['number of open complaints'] = data_frame1['number of open complaints'].fillna('0.0')

##added NaN as 0.0 because it is the most common

# %%
data_frame1['vehicle class'].value_counts(dropna=True)
# Out:
# Four-Door Car    5200
# Two-Door Car     2112
# SUV              2009
# Sports Car        548
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64

# %%
data_frame1['vehicle class'] = data_frame1['vehicle class'].fillna('Unspecified')

##added NaN as 'Unspecified' because it is not specified

# %%
data_frame1['vehicle size'].value_counts(dropna=True)
# Out:
# Medsize        7233
# Small          1962
# Large          1070
# Unspecified     608
# Name: vehicle size, dtype: int64

# %%
data_frame1['vehicle size'] = data_frame1['vehicle size'].fillna('Unspecified')

##added NaN as Medsize because it is unspecified

# %%
## Did manually but data_frame['state'] = data_frame['state'].fillna(data_frame['state'].value_counts().head(1)) Would have also worked!


data_frame1
# Out:
#       customer       state  customer lifetime value   response  coverage  \
# 0      DK49336     Arizona              4809.216960         No     Basic
# 1      KX64629  California              2228.525238         No     Basic
# 2      LZ68649  Washington             14947.917300         No     Basic
# 3      XL78013      Oregon             22332.439460        Yes  Extended
# 4      QA50777      Oregon              9025.067525         No   Premium
# ...        ...         ...                      ...        ...       ...
# 10905  FE99816      Nevada             15563.369440         No   Premium
# 10906  KX53892      Oregon              5259.444853         No     Basic
# 10907  TL39050     Arizona             23893.304100         No  Extended
# 10908  WA60547  California             11971.977650         No   Premium
# 10909  IV32877  California              6857.519928  undefined     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
percent_missing = data_frame1.isnull().sum() * 100 / len(data_frame1)
missing_value_data = pd.DataFrame({'column_name': data_frame1.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_data
# Out:
#                                                  column_name  percent_missing
# customer                                            customer              0.0
# state                                                  state              0.0
# customer lifetime value              customer lifetime value              0.0
# response                                            response              0.0
# coverage                                            coverage              0.0
# education                                          education              0.0
# effective to date                          effective to date              0.0
# employmentstatus                            employmentstatus              0.0
# gender                                                gender              0.0
# income                                                income              0.0
# location code                                  location code              0.0
# ...

# %%
data_frame1['response'].value_counts(dropna=True)
# Out:
# No           8795
# Yes          1464
# undefined     614
# Name: response, dtype: int64

# %% [markdown]
# # Lab 3

# %%
data_frame.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
data_frame.shape
# Out:
# (10873, 26)

# %%
data_frame.describe().T
# Out:
#                                  count          mean           std  \
# customer lifetime value        10873.0   8016.881720   6884.829202
# income                         10873.0  37537.101444  30362.078350
# monthly premium auto           10873.0     93.216684     34.454801
# months since last claim        10250.0     15.145073     10.078893
# months since policy inception  10873.0     48.098777     27.929932
# number of open complaints      10250.0      0.383512      0.911190
# number of policies             10873.0      2.977467      2.397752
# total claim amount             10873.0    434.902879    292.233402
# month                          10873.0      1.466661      0.498910
# quarter                        10873.0      1.000000      0.000000
#
#                                        min          25%           50%  \
# customer lifetime value        1898.007675  4014.453113   5768.830622
# income                            0.000000     0.000000  33811.000000
# ...

# %%
data_frame.describe(include=[object]).T
# Out:
#                    count unique            top  freq
# customer           10873   9134        DQ50258     5
# state              10259      5     California  3548
# response           10259      2             No  8795
# coverage           10873      3          Basic  6635
# education          10873      5       Bachelor  3259
# effective to date  10873     59        1/27/11   239
# employmentstatus   10873      5       Employed  6764
# gender             10873      2              F  5554
# location code      10873      3       Suburban  6879
# marital status     10873      3        Married  6298
# policy type        10873      3  Personal Auto  8102
# policy             10873      9    Personal L3  4108
# renew offer type   10873      4         Offer1  4471
# sales channel      10873      4          Agent  4111
# vehicle class      10265      6  Four-Door Car  5200
# vehicle size       10265      3        Medsize  7233

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(data_frame1['response'])
plt.show()

# %%
sns.histplot(binwidth=0.5, x="sales channel", hue="response", data=data_frame1, stat="count", multiple="stack")
# Out:
# <Axes: xlabel='sales channel', ylabel='Count'>

# %%
sns.barplot(x="response", y="income", data=data_frame1)
plt.show()

# %%
sns.catplot(x="response", y="total claim amount", data=data_frame1)
plt.show()

# %%
sns.lineplot(x="response", y="total claim amount", data=data_frame1)
plt.show()
